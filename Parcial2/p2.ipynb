# %% [markdown]
# <a href="https://colab.research.google.com/github/JsNcAr/Metodos1_JasonArias_AngieRicaurte/blob/ramaALRR/p2_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import tqdm

# %%
def ring_a_radius(r, N):
    """
    Return a list of N points in the ring of radius r
    """
    theta = np.random.uniform(0, 2*np.pi, N)
    x = r*np.cos(theta)
    y = r*np.sin(theta)
    return x, y

# %%
def E_x_integrate_function(phi, x, y, z, a=0.5):
    num = x-a*np.cos(phi)
    den = (x**2+y**2+z**2+a**2-2*a*x*np.cos(phi)-2*a*y*np.sin(phi))**(3/2)
    return num/den

# %%
def E_y_integrate_function(phi, x, y, z, a=0.5):
    num = y-a*np.sin(phi)
    den = (x**2+y**2+z**2+a**2+2*a*x*np.cos(phi)-2*a*y*np.sin(phi))**(3/2)
    return num/den

# %%
def E_z_integrate_function(phi, x, y, z, a=0.5):
    num = z
    den = (x**2+y**2+z**2+a**2+2*a*x*np.cos(phi)-2*a*y*np.sin(phi))**(3/2)
    return num/den

# %%
def points_in_ring(r, N):
    """
    Return a list of N points in the ring of radius r
    """
    theta = np.random.uniform(0, 2*np.pi, N)
    x = r*np.cos(theta)
    y = r*np.sin(theta)
    return x, y

# %%
def MonteCarlo_Integral_3D(f, a, b, N):
    x = np.random.uniform(a, b, N)
    y = np.random.uniform(a, b, N)
    z = np.random.uniform(a, b, N)
    phi = np.random.uniform(0, 2*np.pi, N)
    return ((b-a)**3)*np.sum(f(phi, x, y, z))/N

# %% [markdown]
# def simpson(f, a, b,x,y,z, n=100):
#     h = (b-a)/n
#     phi = np.linspace(a, b, n+1)
#     y = f(phi, x, y, z)
#     return h/3 * np.sum(y[0:-1:2] + 4*y[1::2] + y[2::2])

# %%
M_Ring = MonteCarlo_Integral_3D

Sample = np.zeros(M_Ring.shape[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 M_Ring = Montecarlo_ring(0.5, 100000)
#       3 Sample = np.zeros(M_Ring.shape[0])
#
# NameError: name 'Montecarlo_ring' is not defined

# %%
def MC_p(f, M_Ring, Sample):
    for i in range(M_Ring.shape[0]):
        Sample[i] = f(M_Ring[i, 0], M_Ring[i, 1],M_Ring[i, 2])
    return Sample

# %%
def E_field(x, y, z, a=0.5):
    Ex = MC_p(E_x_integrate_function, M_Ring, Sample)/(2*np.pi)
    Ey = MC_p(E_y_integrate_function, M_Ring, Sample) / (2 * np.pi)
    Ez = MC_p(E_z_integrate_function, M_Ring, Sample) / (2 * np.pi)
    return Ex, Ey, Ez

# %%
print(E_field(0.6, 0.6, 1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(E_field(0.6, 0.6, 1))
#
# Cell In[12], line 2, in E_field(x, y, z, a)
#       1 def E_field(x, y, z, a=0.5):
# ----> 2     Ex = MC_p(E_x_integrate_function, M_Ring, Sample)/(2*np.pi)
#       3     Ey = MC_p(E_y_integrate_function, M_Ring, Sample) / (2 * np.pi)
#       4     Ez = MC_p(E_z_integrate_function, M_Ring, Sample) / (2 * np.pi)
#
# Cell In[11], line 3, in MC_p(f, M_Ring, Sample)
#       1 def MC_p(f, M_Ring, Sample):
#       2     for i in range(M_Ring.shape[0]):
# ----> 3         Sample[i] = f(M_Ring[i, 0], M_Ring[i, 1],M_Ring[i, 2])
#       4     return Sample
#
# TypeError: E_x_integrate_function() missing 1 required positional argument: 'z'

# %%
N = 6
x = np.linspace(-0.6, 0.6, N)
y = np.linspace(-0.6, 0.6, N)
z = np.linspace(-0.6, 0.6, N)

# %%
Ex = np.zeros((N, N, N))
Ey = np.zeros((N, N, N))
Ez = np.zeros((N, N, N))

# %%
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(121, projection='3d')
#ax.scatter(X,Y)

for i in range(N):
    for j in range(N):
        for k in range(N):
            Ex[i,j,k], Ey[i,j,k], Ez[i,j,k] = E_field(x[i], y[j], z[k])
            ax.quiver(x[i], y[j], z[k], Ex[i,j,k], Ey[i,j,k], Ez[i,j,k], length=0.5, normalize=True)
x_r, y_r = ring_a_radius(0.5, 100)
ax.scatter(x_r, y_r ,color='red')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.set_xlim(-0.6, 0.6)
ax.set_ylim(-0.6, 0.6)
ax.set_zlim(-0.6, 0.6)
# Out:
# (-0.6, 0.6)
