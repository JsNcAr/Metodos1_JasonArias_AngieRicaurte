# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym

# %%
a = 0
b = 1000
n = 11

# %%
def black_body_radiation(x):
    return (x**3)*np.exp(x) / (np.exp(x) - 1.0)


def Derivative(f, x, h=1e-4):
    return (f(x + h) - f(x - h)) / (2 * h)

def gauss_laguerre(f, a, b, n):
    x, w = np.polynomial.laguerre.laggauss(n)
    z = 0
    for i in range(n):
        t = (0.5) * (2) * (x[i])
        z += w[i] * f(t)
    return z

# %%
I = gauss_laguerre(black_body_radiation, a, b, 3)
print("Integral: ", I)
# Out:
# Integral:  6.481130171540027

# %%
def error_points(n):
    error = np.array([])
    print(n)
    for i in n:
        error = np.append(error, gauss_laguerre(black_body_radiation, a, b, int(i)))
    return error

# %%
n = np.linspace(2, 10, 9)
error = error_points(n)

plt.plot(n, error, 'o')
plt.grid()
plt.xlabel('n')
plt.ylabel('error')
plt.title('Error vs n')
plt.show()
# Out:
# [ 2.  3.  4.  5.  6.  7.  8.  9. 10.]
