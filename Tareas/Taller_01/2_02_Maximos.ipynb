# %% [markdown]
# <a href="https://colab.research.google.com/github/JsNcAr/Metodos1_JasonArias_AngieRicaurte/blob/ramaALRR/Reto1_maximos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import urllib.request
from operator import length_hint

# %%
url="https://raw.githubusercontent.com/asegura4488/Database/main/MetodosComputacionalesReforma/EstrellaEspectro.txt"
filename="DatosMaximo.txt"
urllib.request.urlretrieve(url,filename)
data=np.loadtxt(filename)
plt.plot(data[:,0],data[:,1])

# %%
datos = np.array(data)

x = []
y = []

# %%
def maximos_locales(array):
    maximos=[]
    for i in range(1,len(datos)-1):
        anterior=datos[i-1][1]
        actual_x=datos[i][0]
        actual=datos[i][1]
        siguiente=datos[i+1][1]
        if actual>anterior and actual>siguiente:
            maximos.append([actual_x,actual])
    return maximos

# %%
maximos_l = maximos_locales(datos)

for i in maximos_l:
    coordenada_x = i[0]
    x.append(coordenada_x)
    coordenada_y = i[1]
    y.append(coordenada_y)
plt.scatter(x, y, c="red", label="Maximos locales", s=20, alpha=0.8, marker="o", linewidth=0.5, edgecolor="black")
plt.plot(data[:, 0], data[:, 1], label="Espectro", linewidth=1.5, alpha=0.8,linestyle="-")
plt.legend()
plt.show()
